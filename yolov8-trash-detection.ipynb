# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/trash_classification'
# Out:
# best.pt      data-preprocess.ipynb  train	     train_0508_0500  yolov8-trash-detection.ipynb
# config.yaml  last.pt		    train_0507_2103  val_0507_2103
# data	     README.md		    train_0508_0444  val2

# %%
from zipfile import ZipFile
import shutil
data_path = '/content/drive/MyDrive/Colab Notebooks/trash_classification/data/train.zip'
with ZipFile(data_path) as zipper:
  zipper.extractall('./data/image_classification')

source_directory = "/content/data/image_classification/train/images"
destination_directory = "/content/data/image_classification/images"
shutil.move(source_directory, destination_directory)

source_directory = "/content/data/image_classification/train/labels"
destination_directory = "/content/data/image_classification/labels"
shutil.move(source_directory, destination_directory)
# Out:
# '/content/data/image_classification/labels/labels'

# %%
data_path = '/content/drive/MyDrive/Colab Notebooks/trash_classification/data/val.zip'
with ZipFile(data_path) as zipper:
  zipper.extractall('./data/image_classification')

source_directory = "/content/data/image_classification/val/images/val"
destination_directory = "/content/data/image_classification/images"
shutil.move(source_directory, destination_directory)

source_directory = "/content/data/image_classification/val/labels/val"
destination_directory = "/content/data/image_classification/labels"
shutil.move(source_directory, destination_directory)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-4-43c163bedf0b> in <cell line: 7>()
#       5 source_directory = "/content/data/image_classification/val/images/val"
#       6 destination_directory = "/content/data/image_classification/images"
# ----> 7 shutil.move(source_directory, destination_directory)
#       8
#       9 source_directory = "/content/data/image_classification/val/labels/val"
#
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     812
#     813         if os.path.exists(real_dst):
# --> 814             raise Error("Destination path '%s' already exists" % real_dst)
#     815     try:
#     816         os.rename(src, real_dst)
#
# Error: Destination path '/content/data/image_classification/images/val' already exists

# %%
# directory_path = "/content/data/image_classification"
# shutil.rmtree(directory_path)

# %%
# delete
directory_path = "/content/data/image_classification/train"
shutil.rmtree(directory_path)
directory_path = "/content/data/image_classification/val"
shutil.rmtree(directory_path)

# %%
ROOT_DIR = '/content/drive/MyDrive/Colab Notebooks/trash_classification'

# %%
# !pip install ultralytics
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.5/756.5 kB 9.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# %pip install comet_ml --quiet
import comet_ml
comet_ml.init(project_name='trash-classification')

# %%
from ultralytics import YOLO
import os

model = YOLO('yolov8s.yaml').load('yolov8s.pt')  # build from YAML and transfer weights
results = model.train(
    data=os.path.join(ROOT_DIR, "config.yaml"),
    epochs=300,
    batch=4,
    project="trash-classification",
)
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !scp -r trash-classification/train4 '/content/drive/MyDrive/Colab Notebooks/trash_classification/train_0508_0500'

# %% [markdown]
# # Validation

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/trash_classification/train_0508_0500/weights'
# Out:
# best.pt  last.pt

# %%
from ultralytics import YOLO

#model = YOLO('yolov8m.pt')
model = YOLO('/content/drive/MyDrive/Colab Notebooks/trash_classification/train_0508_0500/weights/best.pt')

metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# YOLOv8s summary (fused): 168 layers, 11144160 parameters, 0 gradients, 28.5 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 22.9MB/s]
# val: Scanning /content/data/image_classification/labels/val... 469 images, 0 backgrounds, 0 corrupt: 100%|██████████| 469/469 [00:00<00:00, 1314.66it/s]
# val: New cache created: /content/data/image_classification/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 30/30 [00:09<00:00,  3.14it/s]
#                    all        469        750       0.72      0.611      0.653      0.566
#    Fast food container        469         20      0.713       0.75      0.719      0.565
#             Book paper        469          7      0.397      0.286      0.364      0.147
#             Power bank        469         21      0.895          1      0.993      0.959
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !scp -r runs/detect/val '/content/drive/MyDrive/Colab Notebooks/trash_classification/val_0508_0500'
